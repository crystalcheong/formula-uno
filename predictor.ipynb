# %%
# %pip install -q fastf1
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 2.0.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import fastf1
fastf1.ergast.interface.BASE_URL = "https://api.jolpi.ca/ergast/f1"

# %%
import fastf1
fastf1.Cache.enable_cache("cache")
session=fastf1.get_session(2024,'Zandvoort','Race')
session.load()
# Out:
# core           INFO 	Loading data for Dutch Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 4             4      L NORRIS          NOR           norris          McLaren
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 10           10       P GASLY          GAS            gasly           Alpine
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# ...

# %%
session.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0   0 days 00:00:40.176000     18.7      65.0    1019.9     False       31.6
# 1   0 days 00:01:40.176000     18.7      65.0    1019.9     False       31.4
# 2   0 days 00:02:40.188000     18.7      65.0    1020.0     False       31.2
# 3   0 days 00:03:40.198000     18.8      65.0    1019.9     False       31.2
# 4   0 days 00:04:40.189000     18.8      66.0    1019.9     False       31.2
# ..                     ...      ...       ...       ...       ...        ...
# 148 0 days 02:28:40.944000     19.3      57.0    1019.9     False       31.8
# 149 0 days 02:29:40.939000     19.3      57.0    1019.9     False       31.8
# 150 0 days 02:30:40.913000     19.3      57.0    1019.9     False       31.8
# 151 0 days 02:31:40.918000     19.5      57.0    1020.0     False       30.8
# 152 0 days 02:32:40.913000     19.3      58.0    1020.0     False       30.7
#
#      WindDirection  WindSpeed
# ...

# %%
session.get_circuit_info()
# Out:
# CircuitInfo(corners=              X            Y  Number Letter       Angle     Distance
# 0   2045.235718  6685.891602       1          66.665211   343.227974
# 1   1769.605835  3831.817627       2         -18.440573   665.120918
# 2    733.604797  2809.591553       3          29.283872   830.364258
# 3   2716.918945  3031.772217       4         -86.771394  1046.220294
# 4   4555.515137  2861.585693       5          95.349563  1239.104252
# 5   6001.011719  3518.558350       6         -70.125444  1391.074235
# 6   8671.674805  2879.995361       7        -165.843124  1687.550679
# 7   7340.243652   117.993332       8         108.736262  2009.133169
# 8   5498.077637   848.862793       9          -1.483621  2230.926516
# 9   7457.498047  2120.509277      10        -167.375656  2493.821513
# 10  2016.621582  1550.578857      11          79.032802  3060.691296
# 11  1264.387817  1672.332031      12         -38.196035  3149.303673
# ...

# %%
print(session)
# Out:
# 2024 Season Round 15: Dutch Grand Prix - Race

# %%
laps=fastf1.core.Laps(session=session)

# %%
type(laps)
# Out:
# fastf1.core.Laps

# %%
print(laps)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(laps.pick_not_deleted)
# Out:
# <bound method Laps.pick_not_deleted of Empty DataFrame
# Columns: []
# Index: []>

# %%
laps_revised=session.laps
laps.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
session
# Out:
# 2024 Season Round 15: Dutch Grand Prix - Race

# %%
new_session=fastf1.get_session(2021,"Emiglia Romana","race")
# Out:
# events      WARNING 	Correcting user input 'Emiglia Romana' to 'Emilia Romagna Grand Prix'

# %%
new_session
# Out:
# 2021 Season Round 2: Emilia Romagna Grand Prix - Race

# %%
new_session.load()
# Out:
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
new_laps=new_session.laps.copy()

# %%
new_laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 00:35:08.902000    GAS           10 0 days 00:01:54.003000
# 1    0 days 00:37:31.932000    GAS           10 0 days 00:02:23.030000
# 2    0 days 00:39:52.780000    GAS           10 0 days 00:02:20.848000
# 3    0 days 00:42:17.477000    GAS           10 0 days 00:02:24.697000
# 4    0 days 00:44:41.409000    GAS           10 0 days 00:02:23.932000
# ...                     ...    ...          ...                    ...
# 1122 0 days 02:30:43.366000    GIO           99 0 days 00:01:19.761000
# 1123 0 days 02:32:02.940000    GIO           99 0 days 00:01:19.574000
# 1124 0 days 02:33:22.489000    GIO           99 0 days 00:01:19.549000
# 1125 0 days 02:34:42.254000    GIO           99 0 days 00:01:19.765000
# 1126 0 days 02:36:01.737000    GIO           99 0 days 00:01:19.483000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# ...

# %%
#Drop team data i.e. points for constructors etc

session_2024 = fastf1.get_session(2024, 7, "Q")
session_2024.load()
laps_2024 = session_2024.laps[["Driver", "LapTime", "Sector1Time", "Sector2Time", "Sector3Time"]].copy()
laps_2024.dropna(inplace=True)
# Out:
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Qualifying [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
laps_2024
# Out:
#     Driver                LapTime            Sector1Time  \
# 1      VER 0 days 00:01:16.013000 0 days 00:00:23.949000
# 2      VER 0 days 00:01:49.752000 0 days 00:00:36.105000
# 4      VER 0 days 00:01:15.762000 0 days 00:00:23.746000
# 5      VER 0 days 00:01:34.157000 0 days 00:00:30.387000
# 7      VER 0 days 00:01:15.386000 0 days 00:00:23.774000
# ..     ...                    ...                    ...
# 277    ALO 0 days 00:01:45.203000 0 days 00:00:24.427000
# 279    SAR 0 days 00:01:17.188000 0 days 00:00:24.287000
# 280    SAR 0 days 00:01:37.979000 0 days 00:00:29.880000
# 284    SAR 0 days 00:01:16.731000 0 days 00:00:24.130000
# 285    SAR 0 days 00:01:45.032000 0 days 00:00:33.822000
#
#                Sector2Time            Sector3Time
# 1   0 days 00:00:26.337000 0 days 00:00:25.727000
# 2   0 days 00:00:37.328000 0 days 00:00:36.319000
# 4   0 days 00:00:26.348000 0 days 00:00:25.668000
# 5   0 days 00:00:30.154000 0 days 00:00:33.616000
# ...

# %%
session_fp2=fastf1.get_session(2024,7,"FP2")

# %%
session_fp2.load()
# Out:
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Practice 2 [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
session_fp2.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 2             2    L SARGEANT          SAR         sargeant         Williams
# 3             3   D RICCIARDO          RIC        ricciardo               RB
# 4             4      L NORRIS          NOR           norris          McLaren
# 10           10       P GASLY          GAS            gasly           Alpine
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 18           18      L STROLL          STR           stroll     Aston Martin
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# ...

# %%
session_fp2.results.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'Laps'],
#       dtype='object')

# %%
session_fp2.results["GridPosition"]
# Out:
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 10   NaN
# 11   NaN
# 14   NaN
# 16   NaN
# 18   NaN
# 20   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 27   NaN
# 31   NaN
# 44   NaN
# 55   NaN
# 63   NaN
# 77   NaN
# 81   NaN
# Name: GridPosition, dtype: float64

# %%
# clean air race pace from racepace.py
# NOTE: CLEAN AIR RACE PACE IS AVERAGE OF DRIVER LAP RIMES FROM FP2
clean_air_race_pace = {
    "VER": 93.191067, "HAM": 94.020622, "LEC": 93.418667, "NOR": 93.428600, "ALO": 94.784333,
    "PIA": 93.232111, "RUS": 93.833378, "SAI": 94.497444, "STR": 95.318250, "HUL": 95.345455,
    "OCO": 95.682128
}
